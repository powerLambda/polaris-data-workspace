# %%
#Install IPython dependencies via conda
#https://anaconda.org/conda-forge/ipython-sql
#There's a MySQLdb's fork that adds Python 3 support
#%conda install pymysql
# %conda install -c bioconda mysqlclient

# %conda install -c anaconda sqlalchemy


#Install IPython Extension
# %conda install -c conda-forge ipython-sql
# %load_ext sql
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/bitnami/miniconda
#
#   added / updated specs:
#     - mysqlclient
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2021.10.~ --> pkgs/main::ca-certificates-2021.10.26-h06a4308_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              conda-forge::conda-4.11.0-py37h89c186~ --> pkgs/main::conda-4.11.0-py37h06a4308_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/bitnami/miniconda
#
#   added / updated specs:
#     - sqlalchemy
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.10.26~ --> anaconda::ca-certificates-2020.10.14-0
# ...

# %%
# %conda list
# Out:
# # packages in environment at /opt/bitnami/miniconda:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             4.5                       1_gnu
# alembic                   1.7.5                    pypi_0    pypi
# argcomplete               1.12.3                   pypi_0    pypi
# argon2-cffi               21.2.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# async-generator           1.10                     pypi_0    pypi
# attrs                     21.2.0                   pypi_0    pypi
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# bleach                    4.1.0                    pypi_0    pypi
# ...

# %%
from sqlalchemy import create_engine
from MySQLdb import _mysql

# mysql connectivity test
db=_mysql.connect(host="172.17.200.25",port=3306,user="root", passwd="Welcome1@",db="employees")
db.query("""SELECT * FROM departments """)
r=db.store_result()
print('mysqlclient connectivity test success')
print(r.fetch_row())


engine = create_engine("mysql+mysqldb://root:Welcome1@@172.17.200.25/employees")
conn = engine.connect()
print('sqlalchemy connectivity test success')
conn.execute("SELECT * FROM departments").fetchall()
# Out:
# mysqlclient connectivity test success
# ((b'd002', b'2BSJY3XGS3'),)
# sqlalchemy connectivity test success
# [('d002', '2BSJY3XGS3'),
#  ('d006', '2M91KPYQZ5'),
#  ('d005', '8CV9HDC62S'),
#  ('d007', 'DO3M49R13O'),
#  ('d008', 'DQN2N2W0JO'),
#  ('d004', 'LFKF8GHRSY'),
#  ('d003', 'WVK3XQ5TVB'),
#  ('d009', 'X12P2G4YF4'),
#  ('d010', 'Z9U10PVAVF'),
#  ('d001', 'ZT7JPUDZ05')]

# %%
# %%sql mysql+mysqldb://root:Welcome1@@172.17.200.25/employees
# SELECT * FROM departments
# Out:
# 10 rows affected.
# [('d002', '2BSJY3XGS3'),
#  ('d006', '2M91KPYQZ5'),
#  ('d005', '8CV9HDC62S'),
#  ('d007', 'DO3M49R13O'),
#  ('d008', 'DQN2N2W0JO'),
#  ('d004', 'LFKF8GHRSY'),
#  ('d003', 'WVK3XQ5TVB'),
#  ('d009', 'X12P2G4YF4'),
#  ('d010', 'Z9U10PVAVF'),
#  ('d001', 'ZT7JPUDZ05')]

# %%
# %sql SELECT count(*) FROM dept_emp
# Out:
#  * mysql+mysqldb://root:***@172.17.200.25/employees
# 1 rows affected.
# [(331603,)]
